# %% [markdown]
# # DataKind SF DataDive 2017
#
# http://bit.ly/datadive2017
# https://datakindsfbayarea.hackpad.com/DataDive-March-2017-General-Info-eaCE7gz2VCr
#
# ## Day 1
#
# - DataDive
#     - One marathon weekend & partner with orgs on
#         - Data Analysis
#         - Exploration
#         - Prototyping
#     - Three projects, each one has
#         - Data ambassadors
#         - Org reps
#         - Volunteer team
# - Schedule Highlights
#     - Friday
#     - Saturday
#     - Sunday
# - Tools for success
#     - Slack
#     - Hackpad
#     - GitHub => For code, not for data
#     - Google Drive
# - Chatham House Rule
#     - Ask for permission before sharing:
#         - Affiliation
#         - Non-public information
#         - Data and technology
#     - http://chathamhouse.org/about/chatham-house-rule
# - What do I do?
#     - Collaborate: Teams of 15-20 people to accomplish something in 36 hours
#     - Communicate: Ask questions and understand
#     - Stay within scope
# - "It doesn't get easier. You just go faster."
#     - Fix the level of quality you're trying to achieve
#     - Fix your level of effort at the outermost bound of your capability
#         - If you do that, you will always feel something is difficult and always get better at it
# - Double the Donation
#     - datakind.org/donate
# - Organizations
#     - Concrn - Compassionate Crisis Response for Neighbors in Need
#         - Needs dashboard/interface to show their effectiveness
#         - Programs
#         - Skills
#             - Data analysis
#             - Data visualization at executive level
#             - NLP, Analyzing free text
#         - Incorporating other data sets
#             - Incarceration
#             - Ambulance rides
#             - Costs
#         - Tech: R, Python, Excel
#     - Supply Bank
#         - SupplyBank.org
#         - Problems: Prioritization, Interactive
#     - Living Goods
#         - Data Science to Deliver Better Health
#         - SF, Sub-Saharan Africa (Kenya, Uganda)
#         - 5-10% children in third world countries die before 5 years old from malaria, diarrhea, pneumonia
#         - Treatment costs $2
#         - 1 doctor per 24,000 people
#         - Population of 2 million people
#         - Technology:
#             - MedicMobile, Tech NPO that makes apps
#             - "Tool agnostic"
#         - Data Dive Weekend Goals
#             - Complex Data
#             - Complex Problem
# - Getting Started
#     - Talk about the problems & challenges
#     - Meet the DA and Org reps
#     - Planning tasks and teams
#
# ### Living Goods
#
# - Data Ambassadors (technical): Vicky, Sean
# - Subject Matter: Brad (analytic)
# - Goal
#     - Reduce child mortality
#         - Re-prioritizing which households the community house promoters (CHPs) should be visiting
#     - Data does not have child mortality
#         - Hard for CHPs to ask who has died
#     - Treatments & referrals -> Sell products -> Follow-up forms -> Referred to clinic -> Follow up
#     - Two stages
#         - Pregnancy
#         - Young child (0-5)
#     - Think what to predict
#         - Low birth weight
#         - Still births
#     - How to output findings in a way that's useful
#         - 3 output forms
#             - Summary stats
#             - Regression, Causality
#             - Machine learning models (R&D)
#         - Have 2 different groups for data sets
#             - Assessment data sets: sicknesses, referrals
#             - Pregnancy data sets: preg follow-up
#             - Create a predictive score and aggregate them -> Rank the risk
#     - Weekend overview
#         - Sunday
#             - 1pm presentation
#             - 3 hours on Sunday
#         - Saturday
#             - Domain knowledge
#             - Talk about the data itself
#             - How to tie the data to a real world problem
#             - Structure TBD
#             - Hypotheses to explore as a group
#             - Not necessarily a dashboard -> Data in some format
#     - Q&A
#         - What do you wish you had at the end of the weekend?
#             - Insights
#                 - Summary stats: Insights
#                 - Regression: somewhere in the middle
#                 - ML models
#         - Looking for insights from public health/epidemiology perspective for the scope of your problem?
#             - Yes!
#             - Brad knows enough Epi do be deadly
#         - Have you encountered trying to sell them something & they don't have the money to buy?
#             - Trust
#         - What percent of data is external?
#             - All internal
#     - Tomorrow
#         - 10:30am Start
#         - Data released tomorrow
#         - Learn about the problem -> Then get into the data
