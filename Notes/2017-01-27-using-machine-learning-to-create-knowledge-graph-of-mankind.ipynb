# %% [markdown]
# # Using Machine Learning to Create a Knowledge Graph of Mankind
# Dr. Lei Wu, Senior Manager of Data Science @ Ancestry
# - Friday, January 27, 2017
# - University of San Francisco
#
#
# + Kyle Johnson, PhD, Accenture
#
#
# - Agenda
#     - What Data
#     - Answers We Get
#     - Thinking
# - Which is most important to you? => Friends, Jobs, Family
# - Ancestry (est 1983) => Building network to discover family info/family history service
#     - Global leader in family history and consumer genomics
#     - Green leaves => Hints (recommendation system)
# - How their research works
#     - Unstructured data: Collected all the paperwork
#     - Manually scanned all the paperwork into computers to DB
#     - OCR => Recognition to extract the data
# - Record data leads to hints & discoveries
#     - Content + Tools -> "Discoveries"
#     - Content
#         - 20 years and $200 mill investment
#         - 70% proprietary
#         - 200 record categories
#         - 18+ billion historical records, 80+ million family trees, 300+ million user-uploaded photos
#     - Tools
#         - Intelligent searching
#         - Learning algorithms "hint" records and ancestors
#         - "Big Tree" further strengthens moat
#             - Many duplicate nodes in family tree
#             - Try to detach overlaps and connects family trees
#             - **It's not a social network; it's a family network** => Larger than FB networks
#         - Social sharing and collaboration
# - Data Science Team
#     - Deep Learning
#         - Handwritten Recognition
#         - Form classification => **supervised** (200 labels)
#     - NLP
#         - Name correct
#         - Event detection
#     - Optimize Search Engine
#         - Learning to rank
#         - Dimension reduction
#     - Recommendation Engine
#         - Tree hints
#         - Photo hints
#         - DNA hints
# - Flowchart: How do we generate Big Tree?
#     - DB -> Feature Extractor -> Blocking Mechanism -> Persona Compare Engine -> Stitch Engine -> Aggregator -> Evaluator -> Service API
# - Flowchart: ThunderCompare Engine v1.0
#     - Garbage in, garbage out!
# - Flowchart: ThunderCompare Engine v2.0?
#     - Clean
#     - Recycle => Not only informative, but can be used for other data
#     - Discard => Less accurate; can confuse models
#     - ML => Can build model accurately, but machine needs human interaction
#     - Prediction => Once you have first model, get feedback, improve model, learn from model (look into mistakes)
# - Flowchart: Data Architecture
#     - Auto labeler => Gives eval results
# - Performance
#     - iTC: Intelligent engine
#     - 25.8% quality improvement
#     - 130% speed increase
# - Game changing strategies in big tree
#     - Convert data into knowledge Big Tree
#     - Engage users into the modeling loop
#     - Marry human intelligence w/ machine intelligence
#     - Better understanding of human kind w/ big data
#     - Real time adaptation to new information
#     - Personalized family history stories
# - Takeaways
#     - ML = powerful tool for building a knowledge hraph about mandkind
#     - Hire the best data scientists!
