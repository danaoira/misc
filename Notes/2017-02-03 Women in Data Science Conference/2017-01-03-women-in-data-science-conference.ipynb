# %% [markdown]
# # WiDS Conference
#
# Host: Women in Big Data
# Location: Intel SC12
#
# ## Welcome Note
# - Site: www.womeninbigdata.org
# - WIBD Forum Video
#     - Hurdles => Women are the minority
#
# ### Schedule
# - 9:00 Opening Remarks
# - 9:10 Welcome Address
# - 9:30 Morning Keynote
# - 10:10 Break
# - 10:15 Technical Vision Talks
# - 10:55 Break
# - 11:10 Technical Vision Talks
# - 12:10 NetWorking Lunch
# - 1:40 Afternoon Keynote
# - 2:20 Break
# - 2:25 Technical Vision Talks
# - 3:05 Break
# - 3:20 Career Panel
# - 4:14 Technical Vision Talks
# - 4:55 Closing Remarks

# %% [markdown]
# ## Welcome Address
#
# - "It's never been a better time to be a woman in Data Science."
# - "Focus on your strengths and how you can apply those further can be an efficient way to have an impact."

# %% [markdown]
# ## Morning Keynote
#
# Anne Green, Google
#
# - "Data is clearly changing the world."
# - Personal Story
#     - Sailboating
#     - Professor offered to be her adviser
#     - Texas A&M -> Vermont
#     - MIT-> Naval Architecture
#     - SF -> Designing for oil rigs
#     - SoCal -> Worked for Engineering wind surfing sails
#     - UC Berkeley -> MS Computer Science + bf "boring life happened!" => husband is a Stanford professor
#     - Sybase
#     - Tandem Computers
#     - VXTreme
#     - VMWare (10 years) -> Founded by her husband's grad students
#     - More startups & joined boards (Intuit)
#     - Joined board of Google (now AlphaBid)
#     - Worked on Google Cloud architecture
#     - Google Cloud
#         - BigQuery
#             - Spotify: Queries from 4 hours -> 12 seconds
#             - Home Depot: 400TB data warehouse migration
#         - Pokemon GO: What they did was 50x what they predicted what they would do
# - How Google makes ML accessible
#     - Democratize AI
#     - Make it easy to use for everyone in the world
#     - TensorFlow
# - Future of Infrastructure
#     - I(ntelligence)aaS
#     - AI Controlled
#     - Active research (DeepMind)
# - Closing Remarks
#     - "Pay attention to what excites you."
#     - Encourage people to put worries behind you and go forward
# - Q&A
#     - Q: What skillset for people starting out in DS?
#         - Engineering & the more detailed you get about something helps you replicate it
#         - Depends on what you want to optimize for...
#             - Money: ML for Financial Services
#             - Helping the world: Health
#     - Q: ML on job displacement. How should society react to that? What socieconomical effects?
#         - Skilled people won't lose their jobs
#         - It's all about training
#         - Be computer-literate
#         - Important for young people to get a good education
#         - Value older people too
#     - Q: How will DS affect the developing world (ie. South America)?
#         - Makes resources available to everyone in the world
#         - ML getting easier and easier to use
#     - Q: Frigility.. how will the world function if power goes down?
#
# Internet code: 55408553

# %% [markdown]
# ## Technical Vision Talks - University of Utah
#
# - Data Visualization
# - Humans bring knowledge, which makes us unique
# - **Mizbee: A multiscale Synteny Browser**
# - Design Effective Visualization Tools
#     - People like to talk about visualization
#     - **Graphical Perception: Theory, Experimentation and the Application to the Development of Graphical Models**
#     - Easier to visualize changes in position than changes in color
#     - **Design Activity Framework for Visualization Design**
#     - Evaluate our ideas all along the weay
#     - Understand and translate requirements into an approach we can achieve
# - Operationalize real-world goals into actionable tasks
#     - Actionable -> directly reference the data
#     - "Identify good directors"
#     - How can we have a systematic, engineering way to take tasks like this and make it actionable
#     - "Directors" => "movie"
#     - "Good" => high IMDB ratings
#     - "Identify" => movies with high IMDB ratings
#     - Data Counseling
# - Closing Notes
#     - We as DS think a lot about exploration and explanation
#     - Everyone here has a lot of passion and empathy
#     - Encourage you to use your skills for good & empathy
#     - At the end of our data, our end user are humans
# - Q&A
#     - Q: Static vs interactive visualization?
#         - Static => Put as much info w/o overwhelming
#         - Interaction => Don't have to explain it all
#             - About good design & breaking it into something understandable
#     - Q: How important domain knowledge is as a visualization expert?
#         - Learn enough to know gaps of knowledge
#         - Going naively into a project confronts people with assumptions they don't realize they were making
#         - Good to have interview and observational skills
#         - Don't go into it blindly
#         - Understand the language behind it
#     - Q: Next greatest challenge of data visualization?
#         - Good tools for non-programmers to use to make very rich visualizations
#         - Visual literacy: How do we get more people to understand data?
#             - NYTimes: Doesn't publish scatterplots because it's too much for general public to understand

# %% [markdown]
# ## Technical Vision Talks - SAP
#
# - Confession: Not a DS. Degree in fine arts
# - It wasn't about the data; it was about the science
# - The fourth industrial revolution
# - Emerging topics for the world
#     - AI to jobs
#     - Creating gap between tech haves and have-nots
#     - Our planet may not be able to support its future
# - When it comes to business, data is not the problem. What we need is to take the data & apply the creative curiousity and the systematic discipline of science.
# - We have to take the models of the scientists and the computation of the computer scientists and process of the engineers.
# - Project: Barcode of Life
#     - Allows people to explore data & add their own samples
# - Now that we have the data, we need to apply the science
# - Q&A
#     - Q: Tipping point. Taking science to scalable business processes.. what are success factors?
#         - The speed of competition will have amazing impact on how quick your company will grow.
#         - It has to do a lot with the leadership and the competitive position.
#     - Q: If someone is new to DS. Where would you suggest they get started? Degree or training?
#         - Get the degree in FA (lol)
#         - Domain expertise => Don't think about it too narrowly about it.
#             - If you start a degree in a specified field and apply DS to it, you have a leg up over someone who just did the math side of it.
#             - Those people will be the most interesting and employable.
#     - Q: Advice on product development with DS?
#         - Involve the people who will use it at the end
#         - You need everyone to be involved
#         - It's not just about that math; it's also about the enduser

# %% [markdown]
# ## Technical Talks - Western Digital
#
# - 2D NAND -> 3D NAND
# - Use Case 1: Industrialized Data Science
#     - 3D Stacked Memory Structures
#     - Memory holes filled with actual materials
#     - Creating millions of wafers creates tons of memory holes
#     - Pattern Recognition
#         - Have deformations in memory hole
#     - Use ML to find patterns
#         - Random forest and decision trees
#         - Elastic bunch mapping
#         - Calculate the exact roundness of memory holes to invent & create 3D memory
#             - Radius, perimeter, curvature
#         - Clustering algorithms
#         - => Arrive to non-warped memory holes
# - Use Case 2: Correlation & Ranking ML Class of Problems
#     - In this domain, they create data and invent products to bring revenue
#     - Finding Neo! Coreelation and value (non-deterministic)
#     - Permutation and Combination of every known and unknown correlation
#     - Coreelations in Signly factors: ML problems UC 2
#     - Challenges in mf data
#         - Material instability
#         - DPPM: Defects per parts per million
#     - Have to care about all these
#         - Corpus of knowledge
# - Key Parting Note
#     - Hetereskedastic data: Leading edge, higher order complexity in data
#     - Internet of Machinese - High Variability
# - Q&A
#     - Q: Heteroskedastic in wall street?
#         - Wall street has help with trained data
#         - WD has no trained data
#         - Stock market is a classic example of heteroskedastic data
#     - Q: What skills for someone who can do this work? What's better about visual testing?
#         - Skillset
#             - Ability to ask critical questions
#             - Never giving up
#             - Have a passion to go deep and as deep as possible no matter what domain you're in
#         - Visual Testing => Domain experts
#             - They have been testing & know
#             - DS augments their capacity to help them
#     - Q: IT is not always friendly to women. What can women who are in DS do to help women stay.
#         - We're here and we're not going away.

# %% [markdown]
# ## Technical Talks - HRDAG, SF
#
# - Analytical Methods (photos)
#     - Multiple Systems Estimation (MSE)
# - [Clustering and Solving the Right Problem](https://hrdag.org/tech-notes/clustering-and-solving-the-right-problem.html)
# - Q&A
#     - Q: Tech leaders step of to fill the gap of funding research or it will be the next humanitarian crisis
#     - Q: How can we incentivize data science for social good?
#         - Grow the support to infrastructure
#         - Would help if big companies could dedicate some incentive towards data science for social good
#     - Q: What recommendations for skills, experiences for DS for public good?
#         - Be creative in problem solving and open minding
#         - Be comfortable building weird corner cases
#         - Resources
#             - Statisticians Without Borders
#             - DataKind

# %% [markdown]
# ## Technical Vision Talks - Stanford
#
# - Research focus: AI, ML, Computer Vision
# - Democratizing AI for everyone and every business
# - We have entered the age of AI
# - Alan Turing, PhD 1938
#     - Inspired humanity: "How do we build intelligent machines?"
#     - "Best to provide the machine with the best sense organs that money can buy and then teach it to understand and speak English."
#     - Two ingredients to guide AI tech
#         1. Sensing => Visual, Speech, Haptics
#         2. Language => Have to solve the language problem
#             - Semantics
#             - Inference => Prediction
#             - Syntax
# - Blocks World + Natural Language: SHRDLU (1970s)
#     - We can start to build things that Turing imagined
# - 1970s-90s: AI did not progress as fast as we wanted
#     - Challenges of hand-designed rules of inference
#         - Scalability: Hard to anticipate all possibilities
#         - Adaptability: Hard to adapt to new situations
#         - CLosed-World: Will not work for real world
# - 1980s-1990s: Beyond hand-designed rules: ML!
#     - Rule based programming versus ML
#     - ML -> Supervised Learning -> Unsupervised Learning -> Deep Learning -> ANN
# - 1998: Convolutional NNs
# - 2012: AlexNet
#     - Ingredients for Deep Learning
#         1. Neural Network Algorithms
#         2. Big Data
#         3. Hardware GPU
#     - Set off the revolution of DL/AI
# - Terry
#     - Syntax
#         - 3D Vision
#     - Semantics:
#         - Image classification
#         - object detection
#         - Image understanding
#     - Syntax & Semantics
#         3D Vision +
#     - Syntax & Inference
#         - CLEVR
# - Image Captioning
#     - Story writing to bring out semantics
# - Q&A
#     - Q: How do you prevent AI biases? How do you cleanse the bias?
#         - Awareness is a huge part of it
#         - MIPS has workshops to discuss data bias
#         - Need more awareness and research to combat data bias
#     - Q: Is there a role for rule-based learning in the future?
#         - Rule-based system is not necessarily safe
#         - The issues of rule-based systems is not about its safety & security. It's more about inference.
#         - AI and security is an increasingly interesting topic
#         - Google Brain: How to de-identify data?
#         - There is a role for rule-based systems?
#             - We're still very far from understanding knowledge

# %% [markdown]
# *Lunch*

# %% [markdown]
# ## Afternoon Keynote - NSA
#
# - Not everyone who cares about DS understands how to use it
# - 3 high-level missions
#     1. Information Assurance => Support DoD in defending their systems
#     2. Foreign/Signals Intelligence
#     3. Computer Network Operations
# - Mission-Oriented Researcl
#     - HLT
#     - Cyber
#     - Centaur
#     - Fusion Analytics
#     - Vis
#     - Predictive Analysis
# - There's a similarity with what a climber goes through and what we go through with data
# - Messy data -> NSA data is taken from people who don't want them to have it
# - Start with something simple lik ea classification model
# - Alternative: Can you change search to get a slice?
# - How to achieve a goal and maintain efficacy and efficiency in terms of analyst time?
# - A nice way to frame the discussion => Takes the emotion out of it
# - Anticipatory intelligence => Taking what you know about the past and projecting it to the future
# - DS responsibility
#     - Ways to design the decisions
#     - Ways to understand the desicions
# - Anticipatory Thinking
# - Adversarial ML => a big problem
#     - Data poisoning: Manipulating training data so that the machine learning alg learns the wrong patterns
#     - Evasion: Avoiding detection by designing samples that the ML alg don't catch
#     - Astroturfing: Faking reputation data
# - DS are at a similar point
#     - Many of us understand the problem that there is so much good going on that we don't have the time to think about the dark underbelly.
# - Worry about anchor bias
# - Civil Liberties & Privacy Assessments, Big Data & Privacy Risks
#     - Researcher's job is to get there first and make that available
# - Q&A
#     - Q: What research areas are you ahead in?
#         - Cybersecurity work
#         - Very messy language-intensive data
#         - Cryptomath
#     - Q: Where do scientists draw the line of security?
#         - Need to assess that person's understanding of predictive models and analysis
#         - Best Practice:
#             1. Deliver info
#             2. Have follow-up intervention to see what they understood
#             3. Make sure the understand
#         - Make sure people understand what they've got
#     - Q: Is there a place to look at the protocol to feel proud of it and trust it?
#         - That's where she wants to see evolve
#         - If those on the outside could suggest ways that would be comfortable to the community, that could be quantified for those on the inside => win/win
#     - Q: What approach to get rid of adversarial attacks on ML algs?
#         - Suggestion: Capturing what you know about
#             - False news stories
#             - ID covert infiltration
#             - Use cyber taxonomies for attacks
#             - Think about which defenses would work
#     - Whaling => Next step up from phishing

# %% [markdown]
# ##  Reproducible Research
#
# - Multiplicity of Choices & getting worried about doing the right thing
# - Make work reproducible & not worry about what data is right and not right
# - Challenges (photo)
#     - Heterogeneity
#     - Information leaks
#     - Tree and graph integration, uncertainty visualizations
#     - Multiplicity of choices
#     - Reproducibility
# - What are the data?
# - Everything is data!
# - **phyloseq**: [[1](https://joey711.github.io/phyloseq/)] [[2](https://web.stanford.edu/class/bios221/labs/phyloseq/lab_phyloseq.html)]
# - Heteroscedasticity
# - Summary of the study
#     - Data transformation
#     - Subset of data; remove outliers
#     - Filter extra taxa
#     - Choose a distance
#     - Choose ordination method & number of coords
#     - Choose clustering method & # of clusters
#     - Choose underlyinc continuous variable
#     - Choose graphic representation
# - What we need to do: TRANSPARENCY

# %% [markdown]
# ## Technical Vision Talks - Argyleo Sports
#
# - Women have the ability to excel in Data Science.
# - Oil and gas industry
# - Main foundation for digital transformation of the world of DS
# - Timeline
#     - 2012 Data
#     - 2014 Insight
#     - 2017 Intelligence
# - Kayrros, bringing transparency to the energy markets
#     - Oil industry blind to not using data in a holistic manner
# - Key Message
#     - Oil & gas isn't really sexy
#     - Definitely bringing a lot of data
#     - Different types, high frequency, combine everything with hundreds of labels
#     - Visualization: 1D, 2D, 3D, 4D
#     - It's a fantastic playground for data scientists
#     - Have the curiousity to try it
# - The digital transformation
