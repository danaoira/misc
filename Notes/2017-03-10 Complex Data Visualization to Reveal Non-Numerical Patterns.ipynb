# %% [markdown]
# # Complex Data Visualization to Reveal Non-Numerical Patterns
#
# ## Elijah Meeks, Senior Data Visualization Engineer
#
# @Elijah_Meeks
#
# - USF Alum, Honors Philosophy Major

# %% [markdown]
# - Data Vis products, Vis Eng Team
# - Dashboards, Charts, Fancy things
# - Understand algorithms
# - Data Vis in operations(DevOps)
# - Data Vis in content - how different titles are selected and how they perform from creative perspective

# %% [markdown]
# - **Classical Example: Edward Tufte, Map of Napolean's conquer**
#     - Napolean's troops
#     - Temperature
#     - Path they took
#     - Survival rate
# - **Example: Hex Bin**
# - Example: Flame graphs**
#     - DevOps perspective
#     - Performance analysis of website/application
#
# - What are we trying to see with data vis?
#     - A diagram like Napolean allows a lot of encoding
#     - Data vis people use lots of channels
#     - What happens: Busy exec wasn't interested in that data
#         - Just wants to know how many napoleons went in & returned
# - What do we need complex visualization for?
#     - Data: Stereotyped as numerical
#         - Only valid forms are charts that represent numerical data precisely
#     - Rectangles easier to read than circles
#     - Not all patterns are numericals
#         - Systematic
#         - Hierarchical
#         - Topological
#             - Sacrifice numerical precision to encode other data types
#     - Voronoi vs heat map?
#     - The people creating them need to make diagrams for the people they're creating the for need to be able to read them
#
# - Why use them?
#     - Cool / smart => NO
#     - Complex charts: Show systems and context
#     - Charts aren't for the sake of doing charts
#
# - Not everything is numericals
#     - **Classical Example: Anscombe's quartet**
#     - Bar chart vs network diagram
#         - Network diagram: Numerical data is obscured
#
# - The way you experience Netflix isn't numerical
#     - Oversimplifying the way someone experiences a product w/ a bar chart doesn't give the whole picture
#     - If you can assign a p-value, use a bar chart
#
# - Why use Complex Data Vis?
#     - Photos
#
# - Unanswerable Questions
#     - Photos
#
# - Why do they fail?
#     - Data Vis = Rhetorical moment w/ you and your audience
#     - **Example: Gestalt principles of visual perception**
#         - Can influence and damange the ability of reader to undrstand the concepts being relayed
#
# - Rectangles
#     - Not about better or worse => About effective and less effective
#
# - The Spatial Problem
#     - Proximity indicates similarity and when it doesn't, you need to account for that
#
# - Signal Noise
#
# - Good things
#     - Few channels
#     - More context
#     - Teach people literacy through context
#
# - Resist the Quantitative
#     - Numerical precision: Bar/line chart
#
# - Proximity Abounds
#     - Find ways to de-emphasize unintentional signals ou're sending
#
# - Expect Failure
#
# - Data Vis professionals need to teach DV literacy
#     - Precise Numeric Clean (Data Visualization typically seen as a skill)
#         - Stephen Few
#         - Data Analyst > Data Scientist > Data Visualization Engineer
#     - Designed Engaging Complex (Data Visualization typically seen as a vocation)
#         - IIB Awards
#         - Journalist > Consultant > Artist
#
# - Push Boundaries: But have a frame of reference
#     - Example: Connected scatter plot
#
# - Don't overload channels
#     - Example: Circle pack
#     - Actively de-emphasize
#         - Color var
#         - What you're incoding
#
# - Delight is valuable
#     - There's a value to catching people's attention
#         - Worth sacrificing some of the info channels
#
# - Annotate Everything
#     - Susie Lu, 2017
